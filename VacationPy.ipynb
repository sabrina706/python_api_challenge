# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0           qaqortoq  60.7167  -46.0333      1.33        98
# 1        1  port-aux-francais -49.3500   70.2167      3.50        80
# 2        2        peace river  56.2501 -117.2860     -0.19        98
# 3        3     puerto natales -51.7236  -72.4875      7.94        91
# 4        4               tual  -5.6667  132.7500     29.23        73
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        5.69      GL  1730449308
# 1          32       13.52      TF  1730449309
# 2         100        0.00      CA  1730449310
# 3         100        0.73      CL  1730449268
# 4          23        4.49      ID  1730449314

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Ensure that hvplot and holoviews are installed
# !pip install hvplot holoviews

# Import the necessary modules
import hvplot.pandas  # enables hvplot for pandas DataFrames
import holoviews as hv
hv.extension('bokeh')  # necessary for interactive plotting in Jupyter

# Configure the map plot
humidity_map_plot = city_data_df.hvplot.points(
    x='Lng',  
    y='Lat',  
    geo=True,  
    tiles='OSM',  
    color='blue',  
    size="Humidity",
    title='City Locations'
)

# Display the map
humidity_map_plot
# Out:
# Requirement already satisfied: hvplot in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.11.1)
# Requirement already satisfied: holoviews in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (1.19.1)
# Requirement already satisfied: param<3.0,>=1.12.0 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from hvplot) (2.1.1)
# Requirement already satisfied: packaging in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from hvplot) (24.1)
# Requirement already satisfied: numpy>=1.21 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from hvplot) (2.1.2)
# Requirement already satisfied: colorcet>=2 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from hvplot) (3.1.0)
# Requirement already satisfied: panel>=1.0 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from hvplot) (1.5.3)
# Requirement already satisfied: bokeh>=3.1 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from hvplot) (3.6.0)
# Requirement already satisfied: pandas>=1.3 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from hvplot) (2.2.3)
# Requirement already satisfied: pyviz-comms>=2.1 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from holoviews) (3.0.3)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bokeh>=3.1->hvplot) (6.0.2)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bokeh>=3.1->hvplot) (3.1.4)
# Requirement already satisfied: tornado>=6.2 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bokeh>=3.1->hvplot) (6.4.1)
# Requirement already satisfied: contourpy>=1.2 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bokeh>=3.1->hvplot) (1.3.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bokeh>=3.1->hvplot) (11.0.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bokeh>=3.1->hvplot) (2024.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=1.3->hvplot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=1.3->hvplot) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas>=1.3->hvplot) (2024.2)
# Requirement already satisfied: markdown-it-py in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from panel>=1.0->hvplot) (3.0.0)
# Requirement already satisfied: bleach in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from panel>=1.0->hvplot) (6.2.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from panel>=1.0->hvplot) (0.4.2)
# Requirement already satisfied: requests in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from panel>=1.0->hvplot) (2.32.3)
# Requirement already satisfied: linkify-it-py in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from panel>=1.0->hvplot) (2.0.3)
# Requirement already satisfied: typing-extensions in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from panel>=1.0->hvplot) (4.12.2)
# Requirement already satisfied: markdown in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from panel>=1.0->hvplot) (3.7)
# Requirement already satisfied: tqdm in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from panel>=1.0->hvplot) (4.66.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from Jinja2>=2.9->bokeh>=3.1->hvplot) (3.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.2->pandas>=1.3->hvplot) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from bleach->panel>=1.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from linkify-it-py->panel>=1.0->hvplot) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from markdown-it-py->panel>=1.0->hvplot) (0.1.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->panel>=1.0->hvplot) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->panel>=1.0->hvplot) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->panel>=1.0->hvplot) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests->panel>=1.0->hvplot) (3.4.0)
# Requirement already satisfied: colorama in c:\users\sabri\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm->panel>=1.0->hvplot) (0.4.6)
# [notice] A new release of pip is available: 23.0.1 -> 24.3.1
# [notice] To update, run: C:\Users\sabri\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1028'>
#   <div id="e59af4e7-5e5b-42a7-97b8-df054560aa1a" data-root-id="p1028" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"c55a22d1-fb1e-4dca-991d-45d80735aea3":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1028"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1029","attributes":{"plot_id":"p1028","comm_id":"2ccc078930bd44e4ba110c1df67bbce6","client_comm_id":"724cb2157e0a4f118f023c2c1096c384"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"c55a22d1-fb1e-4dca-991d-45d80735aea3","roots":{"p1028":"e59af4e7-5e5b-42a7-97b8-df054560aa1a"},"root_ids":["p1028"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[179], line 10
#       7 hv.extension('bokeh')  # necessary for interactive plotting in Jupyter
#       9 # Configure the map plot
# ---> 10 humidity_map_plot = city_data_df.hvplot.points(
#      11     x='Lng',
#      12     y='Lat',
#      13     geo=True,
#      14     tiles='OSM',
#      15     color='blue',
#      16     size="Humidity",
#      17     title='City Locations'
#      18 )
#      20 # Display the map
#      21 humidity_map_plot
#
# File ~\anaconda3\Lib\site-packages\hvplot\plotting\core.py:1672, in hvPlotTabular.points(self, x, y, **kwds)
#    1614 def points(self, x=None, y=None, **kwds):
#    1615     """
#    1616     A `points` plot visualizes positions in a 2D space. This is useful for example for
#    1617     geographic plots.
#    (...)
#    1670     - HoloViews: https://holoviews.org/reference/elements/bokeh/Points.html
#    1671     """
# -> 1672     return self(x, y, kind='points', **kwds)
#
# File ~\anaconda3\Lib\site-packages\hvplot\plotting\core.py:95, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#      92         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      93         return pn.panel(plot, **panel_dict)
# ---> 95 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File ~\anaconda3\Lib\site-packages\hvplot\plotting\core.py:102, in hvPlotBase._get_converter(self, x, y, kind, **kwds)
#     100 y = y or params.pop('y', None)
#     101 kind = kind or params.pop('kind', None)
# --> 102 return HoloViewsConverter(self._data, x, y, kind=kind, **params)
#
# File ~\anaconda3\Lib\site-packages\hvplot\converter.py:620, in HoloViewsConverter.__init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, robust, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, downsample, resample_when, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, tiles_opts, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, autorange, **kwds)
#     618 self.dynamic = dynamic
#     619 self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 620 self.crs = self._process_crs(data, crs) if self.geo else None
#     621 self.output_projection = self.crs
#     622 self.project = project
#
# File ~\anaconda3\Lib\site-packages\hvplot\converter.py:953, in HoloViewsConverter._process_crs(self, data, crs)
#     950     _crs = crs
#     952 try:
# --> 953     return process_crs(_crs)
#     954 except ValueError as e:
#     955     # only raise error if crs was specified in kwargs
#     956     if crs:
#
# File ~\anaconda3\Lib\site-packages\hvplot\util.py:283, in process_crs(crs)
#     281     missing.append('pyproj')
#     282 if missing:
# --> 283     raise ImportError(f'Geographic projection support requires: {", ".join(missing)}.')
#     285 if crs is None:
#     286     return ccrs.PlateCarree()
#
# ImportError: Geographic projection support requires: cartopy, geoviews, pyproj.

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
cities_narrow_lats_df = city_data_df[(city_data_df['Lat'] >= -19) & (city_data_df['Lat'] <= 40)]

# Drop any rows with null values
ideal_weather_city_df = cities_narrow_lats_df.dropna()

# Display sample data
ideal_weather_city_df

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather_city_df[['City', 'Country','Lat', 'Lng', 'Humidity']]
hotel_df = hotel_df.copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df.loc[:, 'Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
#                  City Country      Lat       Lng  Humidity Hotel Name
# 4                tual      ID  -5.6667  132.7500        73
# 7          laojunmiao      CN  39.8333   97.7333        36
# 8    minas de marcona      PE -15.2119  -75.1103        87
# 10             tobruk      LY  32.0836   23.9764        60
# 12     ribeira grande      PT  38.5167  -28.7000       100
# ..                ...     ...      ...       ...       ...        ...
# 586          naranjal      EC  -2.6667  -79.6167        89
# 587    nova xavantina      BR -14.6667  -52.3500        97
# 589            dholka      IN  22.7167   72.4667        19
# 590            loreto      MX  22.2667 -101.9667        65
# 591          dargecit      TR  37.5454   41.7197        19
#
# [303 rows x 6 columns]

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000 
params = {
    "categories": "accommodation.hotel",
    "apiKey":geoapify_key  
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    latitude = row['Lat']
    longitude = row['Lng']

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address =requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# tual - nearest hotel: Suita
# laojunmiao - nearest hotel: No hotel found
# minas de marcona - nearest hotel: No hotel found
# tobruk - nearest hotel: فندق زهرة البطنان -طبرق
# ribeira grande - nearest hotel: Hospedaria JSF
# wenling - nearest hotel: Koro
# cabo san lucas - nearest hotel: Comfort Rooms
# sake - nearest hotel: No hotel found
# xiaoweizhai - nearest hotel: 7Days Inn Duyun Bus Terminal Station
# pemangkat - nearest hotel: Hotel Kelapa Gading
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# utrik - nearest hotel: No hotel found
# regeneracao - nearest hotel: Hotel Central
# bonthe - nearest hotel: No hotel found
# tocoa - nearest hotel: Gran Hotel Yadaly
# tura - nearest hotel: Hotel Polo Orchid
# mermoz boabab - nearest hotel: La maison blanche
# ziniare - nearest hotel: Residence Les Saints Innocents
# zuni pueblo - nearest hotel: Inn at Halona
# dwarka - nearest hotel: The Dwarika Hotel
# batarasa - nearest hotel: Business Suites Hotel
# georgetown - nearest hotel: Page 63 hostel
# bac lieu - nearest hotel: Khách sạn Bạc Liêu
# bardai - nearest hotel: No hotel found
# puerto armuelles - nearest hotel: Coco del Mar
# kidal - nearest hotel: No hotel found
# fort bragg - nearest hotel: Airborne Inn Lodging
# newman - nearest hotel: No hotel found
# port moresby - nearest hotel: The Sanctuary Hotel and Spa
# san patricio - nearest hotel: No hotel found
# weston - nearest hotel: TownePlace Suites Fort Lauderdale Weston
# lompoc - nearest hotel: Red Roof Inn Lompoc
# katpur - nearest hotel: No hotel found
# remire-montjoly - nearest hotel: Complexe Belova
# lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# luganville - nearest hotel: Beachfront Resort
# el porvenir - nearest hotel: No hotel found
# las vegas - nearest hotel: Downtown Grand
# viqueque - nearest hotel: Hotel Wailakurini
# enewetak - nearest hotel: No hotel found
# afaahiti - nearest hotel: Omati Lodge
# mili - nearest hotel: No hotel found
# alotau - nearest hotel: Alotau International Hotel
# red hill - nearest hotel: No hotel found
# dakhla - nearest hotel: Hotel Ayouz
# ramadi - nearest hotel: فندق الانبار الدولي
# mayahi - nearest hotel: No hotel found
# tindouf - nearest hotel: محمد بوسبي
# belel - nearest hotel: No hotel found
# dhidhdhoo - nearest hotel: Cinnamon Island
# flying fish cove - nearest hotel: Christmas Island Lodge
# quelimane - nearest hotel: Mabassa
# sabang - nearest hotel: Sabang Hill
# alice - nearest hotel: La Quinta Inn & Suites
# minab - nearest hotel: هتل صدف
# uturoa - nearest hotel: Hawaiki Nui hotel
# tsirang - nearest hotel: No hotel found
# gunnison - nearest hotel: No hotel found
# puerto baquerizo moreno - nearest hotel: Dory's House
# hengyang - nearest hotel: 天心宾馆
# nanning - nearest hotel: No hotel found
# nea alikarnassos - nearest hotel: Hotel Sofia
# kodinar - nearest hotel: Hotel
# lusambo - nearest hotel: No hotel found
# bel ombre - nearest hotel: Villa La Cachette
# saipan - nearest hotel: Chalan Kanoa Beach Hotel
# harar - nearest hotel: Ejersa Hotel
# hotan - nearest hotel: Hua Yi International Hotel (accepts foreigners)
# namie - nearest hotel: HOTELなみえ
# mizque - nearest hotel: Hotel Mavi
# tamandare - nearest hotel: Pousada Baia dos Corais
# arteche - nearest hotel: No hotel found
# antonio enes - nearest hotel: Hotel Quirimbas
# west island - nearest hotel: Cocos Village Bungalows
# mejit - nearest hotel: No hotel found
# wuxue - nearest hotel: No hotel found
# dapa - nearest hotel: Island Suites
# barclayville - nearest hotel: No hotel found
# jijiga - nearest hotel: Africa Hotel
# bhamo - nearest hotel: Winlight Hotel
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# lihue - nearest hotel: Kauai Palms
# santiago de cao - nearest hotel: Hostal El Encanto
# zunyi - nearest hotel: 香山宾馆
# ta`u - nearest hotel: No hotel found
# cadale - nearest hotel: No hotel found
# san pa tong - nearest hotel: River Hotel
# manokwari - nearest hotel: Hotel Arfak
# muli - nearest hotel: No hotel found
# hawaiian paradise park - nearest hotel: No hotel found
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# kasempa - nearest hotel: Kasmpa Council Guest House
# atafu village - nearest hotel: No hotel found
# cabedelo - nearest hotel: No hotel found
# crete - nearest hotel: Eleonas Traditional Cottages
# villanueva - nearest hotel: Hotel Leiva
# kapa'a - nearest hotel: Pono Kai Resort
# la'ie - nearest hotel: No hotel found
# pisco - nearest hotel: La Portada
# hamilton - nearest hotel: North Vista Manor
# goure - nearest hotel: No hotel found
# wanning - nearest hotel: No hotel found
# barreirinhas - nearest hotel: Pousada Matriz
# espanola - nearest hotel: Santa Claran Hotel & Casino
# akcadag - nearest hotel: No hotel found
# chizhou - nearest hotel: 葡萄园大酒店
# valsad - nearest hotel: No hotel found
# phongsali - nearest hotel: Phonsaly Hotel
# xinyuan - nearest hotel: No hotel found
# nova sintra - nearest hotel: Residência Ka Dencho
# mentekab - nearest hotel: Jelai Hotel
# pontianak - nearest hotel: Golden Tulip Hotel
# blackwell - nearest hotel: Holiday Inn Express
# burang - nearest hotel: No hotel found
# taroa - nearest hotel: No hotel found
# cuamba - nearest hotel: Pensao Cariaco
# jauja - nearest hotel: Hostal Sol de Oro
# duyun - nearest hotel: 7Days Inn Duyun Bus Terminal Station
# oriximina - nearest hotel: No hotel found
# kulhudhuffushi - nearest hotel: No hotel found
# zakynthos - nearest hotel: Phoenix Hotel
# vila franca do campo - nearest hotel: Vinha d'Areia Beach Hotel
# bure - nearest hotel: belay zeleke hotel
# pasuquin - nearest hotel: Villa del Marj
# kayangel - nearest hotel: No hotel found
# shingu - nearest hotel: ホテルニューパレス
# naze - nearest hotel: ビジネス旅館畠山
# ternate - nearest hotel: Boulivard ternate
# pitimbu - nearest hotel: Pousada Brisa Mar
# manaure - nearest hotel: hotel palaima
# modakeke - nearest hotel: No hotel found
# mettur - nearest hotel: Tamilnadu Mettur
# ciudad bolivar - nearest hotel: Paoca
# champerico - nearest hotel: Hotel y Restaurante El Submarino
# high rock - nearest hotel: No hotel found
# inirida - nearest hotel: Residencias El Turista del Guainia
# amroli - nearest hotel: No hotel found
# waimea - nearest hotel: No hotel found
# araguari - nearest hotel: Palace Hotel
# el nido - nearest hotel: Dragonfly
# laguna - nearest hotel: Holiday Inn Express & Suites
# bayramaly - nearest hotel: No hotel found
# jequie - nearest hotel: Hotel Bizzon
# aransas pass - nearest hotel: Executive Inn & Suites
# meulaboh - nearest hotel: Hotel Meuligou
# marka - nearest hotel: Salsabiil Hotel
# mpika - nearest hotel: Melody Lodge
# nueva gerona - nearest hotel: Hotel Bamboo
# antsiranana - nearest hotel: Central
# acarau - nearest hotel: No hotel found
# kofele - nearest hotel: No hotel found
# fada - nearest hotel: No hotel found
# jinchang - nearest hotel: No hotel found
# soio - nearest hotel: Hotel Maria Teres
# kasoa - nearest hotel: New Timers Hotel
# pauini - nearest hotel: No hotel found
# goundam - nearest hotel: No hotel found
# simenqian - nearest hotel: No hotel found
# praia da vitoria - nearest hotel: Salles
# san antonio de pale - nearest hotel: No hotel found
# kassiri - nearest hotel: No hotel found
# udon thani - nearest hotel: UDtel
# kertih - nearest hotel: Hotel Singgah
# antalaha - nearest hotel: Hôtel Florida
# johi - nearest hotel: No hotel found
# palikir - national government center - nearest hotel: Mangrove Bay Hotel
# tazacorte - nearest hotel: App Leyma
# muisne - nearest hotel: Hostal Té de Menta
# puerto madero - nearest hotel: No hotel found
# dunbar - nearest hotel: Dunbar Plaza Hotel
# tinajo - nearest hotel: No hotel found
# rambha - nearest hotel: No hotel found
# pearsall - nearest hotel: Pearsall Inn & Suites
# salinopolis - nearest hotel: Hotel Salinópolis
# tofol - nearest hotel: Nautilus Resort
# edremit - nearest hotel: Adramis Termal Otel
# hithadhoo - nearest hotel: Pebbles Inn
# hanzhong - nearest hotel: 东珅国宾大酒店
# kutum - nearest hotel: No hotel found
# hirara - nearest hotel: 古謝そば屋
# puyang chengguanzhen - nearest hotel: 贝壳酒店
# sao raimundo nonato - nearest hotel: Pousada Lelinha
# fale old settlement - nearest hotel: No hotel found
# touros - nearest hotel: Pousada Atlântico
# kisangani - nearest hotel: Hotel Kisangani
# natal - nearest hotel: Natal Palace Hotel
# morehead city - nearest hotel: Bask Hotel Big Rock Landing, Trademark Collection by Wyndham
# soure - nearest hotel: Hotel Marajó
# mahina - nearest hotel: Motu Martin
# san mariano - nearest hotel: No hotel found
# hasaki - nearest hotel: Choshi Plaza Hotel
# hobyo - nearest hotel: Iftin Hotel Hobyo
# sirte - nearest hotel: فندق المدينة-سرت
# weno - nearest hotel: High Tide Hotel
# aracati - nearest hotel: Hotel Complexo Mirante das Gamboas
# pacific grove - nearest hotel: Pacific Grove Inn
# motupe - nearest hotel: Madero Hostal
# montepuez - nearest hotel: Complexo Messalo
# orange city - nearest hotel: 1876 Heritage Inn
# kingston - nearest hotel: Aphrodite Hotel
# mana - nearest hotel: Le Samana
# puerto francisco de orellana - nearest hotel: Gran Hotel del Coca
# kande - nearest hotel: No hotel found
# bechar - nearest hotel: Hôtel Madania
# sinan - nearest hotel: No hotel found
# ciudad melchor muzquiz - nearest hotel: No hotel found
# inarajan village - nearest hotel: No hotel found
# brokopondo - nearest hotel: Matu eiland
# alaghsas - nearest hotel: Hôtel Zagado
# nagqu - nearest hotel: Naqu Hotel
# patacamaya - nearest hotel: Hostal Viña del Mar
# suva - nearest hotel: Extension 68
# tambopata - nearest hotel: La Habana
# puerto leguizamo - nearest hotel: Hotel Girasoles
# nadi - nearest hotel: President Hotel
# ixtapa - nearest hotel: Ma. Cristina
# auki - nearest hotel: No hotel found
# crane - nearest hotel: No hotel found
# jinghong - nearest hotel: No hotel found
# arish - nearest hotel: سينا
# pandan - nearest hotel: No hotel found
# villa yapacani - nearest hotel: No hotel found
# tamanrasset - nearest hotel: فندق الأمان
# kailua-kona - nearest hotel: Kona Seaside Hotel
# hilo - nearest hotel: Dolphin Bay Hotel
# katsuura - nearest hotel: 潮騒の宿
# carutapera - nearest hotel: No hotel found
# gilgit - nearest hotel: PTDC Motel
# tshikapa - nearest hotel: Hôtel TSHAMUNTU
# jeddah - nearest hotel: No hotel found
# juchipila - nearest hotel: Hotel
# west bay - nearest hotel: Bonnie's Arch
# negombo - nearest hotel: Choys Waterfront Residence
# holualoa - nearest hotel: Kona Hotel
# cockburn town - nearest hotel: The Salt Raker Inn
# ypsonas - nearest hotel: Club Aphrodite
# airuk - nearest hotel: No hotel found
# rongelap - nearest hotel: No hotel found
# santa elena de uairen - nearest hotel: Posada Villa Fairmont
# tagiura - nearest hotel: No hotel found
# bikenibeu village - nearest hotel: Otintaai Hotel
# shimoda - nearest hotel: ホテルウラガ
# mangrol - nearest hotel: No hotel found
# tchintabaraden - nearest hotel: No hotel found
# singkil - nearest hotel: No hotel found
# praia - nearest hotel: Casa Sodadi
# lamesa - nearest hotel: Best Western Lamesa Inn and Suites
# coahuayana de hidalgo - nearest hotel: No hotel found
# beni - nearest hotel: Logement Alco-Family
# bafoulabe - nearest hotel: No hotel found
# ataq - nearest hotel: الشارقة بلازا
# ghat - nearest hotel: فندق تاسيلي
# cidade velha - nearest hotel: Encosta Azul
# covington - nearest hotel: North by Hotel Covington
# sinabang - nearest hotel: No hotel found
# lakhdaria - nearest hotel: No hotel found
# tegueste - nearest hotel: Hotel Aguere
# puerto santa - nearest hotel: No hotel found
# savanna-la-mar - nearest hotel: Kibo Hotel
# les cayes - nearest hotel: No hotel found
# umm al quwain city - nearest hotel: Palma Beach Resorts
# camana - nearest hotel: Caja Arequipa
# tsuruoka - nearest hotel: 長寿温泉
# shahr-e babak - nearest hotel: هتل شهرداری
# tarawa - nearest hotel: Betio Lodge
# kinmparana - nearest hotel: No hotel found
# ramhormoz - nearest hotel: No hotel found
# alpine - nearest hotel: Ayres Lodge Alpine
# luorong - nearest hotel: 柳州东城雅和小镇酒店
# turbat - nearest hotel: No hotel found
# ratnagiri - nearest hotel: Vihar
# kingsland - nearest hotel: Hampton Inn Kingsland
# las tablas - nearest hotel: Hotel Don Jesus
# ardakan - nearest hotel: هتل رستوران باغ سرای اردکان
# roxas - nearest hotel: Roxas President's Inn
# mogadishu - nearest hotel: Villa Rays Restaurant & Hotel
# malakanagiri - nearest hotel: No hotel found
# pathein - nearest hotel: Taan Taan Ta
# sao jose da coroa grande - nearest hotel: Hotel do Sol
# nahiyat al fuhud - nearest hotel: No hotel found
# rabaul - nearest hotel: Rabaul Hotel
# guiuan - nearest hotel: Addison Pension House
# shache - nearest hotel: 莎车新盛宾馆
# ponta delgada - nearest hotel: Hotel Talisman
# brigantine - nearest hotel: La Sammana
# at taj - nearest hotel: No hotel found
# palora - nearest hotel: Hotel Sol De Oriente
# paramonga - nearest hotel: Hotel Rico
# peniche - nearest hotel: Residencial Maciel
# fang - nearest hotel: Thipdararat Hotel
# ormara - nearest hotel: No hotel found
# qamdo - nearest hotel: 银杏商务宾馆
# i-n-salah - nearest hotel: باجودة
# piacabucu - nearest hotel: O Leão
# lobujya - nearest hotel: Hôtel Mother Earth
# kas - nearest hotel: KEKOVA OTEL
# serang - nearest hotel: No hotel found
# trairi - nearest hotel: Pousada Villa Aurora
# naranjal - nearest hotel: No hotel found
# nova xavantina - nearest hotel: Hotel Morada do Sol
# dholka - nearest hotel: No hotel found
# loreto - nearest hotel: No hotel found
# dargecit - nearest hotel: Huzur Apart Otel
#                  City Country      Lat       Lng  Humidity  \
# 4                tual      ID  -5.6667  132.7500        73
# 7          laojunmiao      CN  39.8333   97.7333        36
# 8    minas de marcona      PE -15.2119  -75.1103        87
# 10             tobruk      LY  32.0836   23.9764        60
# 12     ribeira grande      PT  38.5167  -28.7000       100
# ..                ...     ...      ...       ...       ...
# 586          naranjal      EC  -2.6667  -79.6167        89
# 587    nova xavantina      BR -14.6667  -52.3500        97
# 589            dholka      IN  22.7167   72.4667        19
# 590            loreto      MX  22.2667 -101.9667        65
# 591          dargecit      TR  37.5454   41.7197        19
#
#                   Hotel Name
# 4                      Suita
# 7             No hotel found
# 8             No hotel found
# 10   فندق زهرة البطنان -طبرق
# 12            Hospedaria JSF
# ..                       ...
# 586           No hotel found
# 587      Hotel Morada do Sol
# 589           No hotel found
# 590           No hotel found
# 591         Huzur Apart Otel
#
# [303 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
import hvplot.pandas
import holoviews as hv
hv.extension('bokeh')

# Configure the map plot
hotel_map = hotel_df.hvplot.points(
    "Lng", "Lat", geo=True, tiles="OSM", 
    frame_width=800, frame_height=600, 
    size="Lat", scale=1, color="City", 
    hover_cols=["Hotel Name", "Country"]
)

# Display the map
hotel_map
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1030'>
#   <div id="ba8e6d9e-1e73-4118-b2f4-5f57797ad3ab" data-root-id="p1030" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"166551dc-2569-4104-be9a-b7dc2d4ada01":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1030"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1031","attributes":{"plot_id":"p1030","comm_id":"e8014a4095a649d3a00391f1a783ec51","client_comm_id":"5425e554d1d34d36abffc6ad688c99b9"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"166551dc-2569-4104-be9a-b7dc2d4ada01","roots":{"p1030":"ba8e6d9e-1e73-4118-b2f4-5f57797ad3ab"},"root_ids":["p1030"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[187], line 6
#       3 hv.extension('bokeh')
#       5 # Configure the map plot
# ----> 6 hotel_map = hotel_df.hvplot.points(
#       7     "Lng", "Lat", geo=True, tiles="OSM",
#       8     frame_width=800, frame_height=600,
#       9     size="Lat", scale=1, color="City",
#      10     hover_cols=["Hotel Name", "Country"]
#      11 )
#      13 # Display the map
#      14 hotel_map
#
# File ~\anaconda3\Lib\site-packages\hvplot\plotting\core.py:1672, in hvPlotTabular.points(self, x, y, **kwds)
#    1614 def points(self, x=None, y=None, **kwds):
#    1615     """
#    1616     A `points` plot visualizes positions in a 2D space. This is useful for example for
#    1617     geographic plots.
#    (...)
#    1670     - HoloViews: https://holoviews.org/reference/elements/bokeh/Points.html
#    1671     """
# -> 1672     return self(x, y, kind='points', **kwds)
#
# File ~\anaconda3\Lib\site-packages\hvplot\plotting\core.py:95, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#      92         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#      93         return pn.panel(plot, **panel_dict)
# ---> 95 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File ~\anaconda3\Lib\site-packages\hvplot\plotting\core.py:102, in hvPlotBase._get_converter(self, x, y, kind, **kwds)
#     100 y = y or params.pop('y', None)
#     101 kind = kind or params.pop('kind', None)
# --> 102 return HoloViewsConverter(self._data, x, y, kind=kind, **params)
#
# File ~\anaconda3\Lib\site-packages\hvplot\converter.py:620, in HoloViewsConverter.__init__(self, data, x, y, kind, by, use_index, group_label, value_label, backlog, persist, use_dask, crs, fields, groupby, dynamic, grid, legend, rot, title, xlim, ylim, clim, robust, symmetric, logx, logy, loglog, hover, subplots, label, invert, stacked, colorbar, datashade, rasterize, downsample, resample_when, row, col, debug, framewise, aggregator, projection, global_extent, geo, precompute, flip_xaxis, flip_yaxis, dynspread, hover_cols, x_sampling, y_sampling, project, tools, attr_labels, coastline, tiles, tiles_opts, sort_date, check_symmetric_max, transforms, stream, cnorm, features, rescale_discrete_levels, autorange, **kwds)
#     618 self.dynamic = dynamic
#     619 self.geo = any([geo, crs, global_extent, projection, project, coastline, features])
# --> 620 self.crs = self._process_crs(data, crs) if self.geo else None
#     621 self.output_projection = self.crs
#     622 self.project = project
#
# File ~\anaconda3\Lib\site-packages\hvplot\converter.py:953, in HoloViewsConverter._process_crs(self, data, crs)
#     950     _crs = crs
#     952 try:
# --> 953     return process_crs(_crs)
#     954 except ValueError as e:
#     955     # only raise error if crs was specified in kwargs
#     956     if crs:
#
# File ~\anaconda3\Lib\site-packages\hvplot\util.py:283, in process_crs(crs)
#     281     missing.append('pyproj')
#     282 if missing:
# --> 283     raise ImportError(f'Geographic projection support requires: {", ".join(missing)}.')
#     285 if crs is None:
#     286     return ccrs.PlateCarree()
#
# ImportError: Geographic projection support requires: cartopy, geoviews, pyproj.
